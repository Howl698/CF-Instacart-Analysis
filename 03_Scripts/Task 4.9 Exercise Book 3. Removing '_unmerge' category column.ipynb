# %% [markdown]
# # Task Exercise 4.9 Book 3. remove '_unmerge' category in 'orders_products_merged.pkl'

# %% [markdown]
# ## Unless removed this category column will prevent customers_checked.csv  merging with 'orders_products_merged.pkl'

# %%
# immporting libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\howl6\OneDrive\Certificates\CareerFoundry\Coursework\Data_Immersion\Chapter 4\Instacart Basket Analysis'

# %%
# import 'orders_products_merged.pkl' dataframe

ords_prods_merge = pd.read_pickle(os.path.join(path,'02_Data','Prepared_Data', 'orders_products_merged.pkl'))

# %%
# view top 5 rows

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2         907        Premium Sliced Bacon       106             12    20.0
# 3         907        Premium Sliced Bacon       106             12    20.0
# 4        1000                    Apricots        18             10    12.9
#
#    order_id user_id  order_number  orders_day_of_week  order_time_of_day  ...  \
# 0   3139998     138            28                   6                 11  ...
# 1   1977647     138            30                   6                 17  ...
# 2   3160996     138             1                   5                 13  ...
# 3   2254091     138            10                   5                 14  ...
# 4    505689     138             9                   6                 12  ...
#
# ...

# %%
# drop column '_merge'

df_ords = ords_prods_merge.drop(columns = ["_merge"])

# %%
# view top 5 rows
df_ords.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2         907        Premium Sliced Bacon       106             12    20.0
# 3         907        Premium Sliced Bacon       106             12    20.0
# 4        1000                    Apricots        18             10    12.9
#
#    order_id user_id  order_number  orders_day_of_week  order_time_of_day  ...  \
# 0   3139998     138            28                   6                 11  ...
# 1   1977647     138            30                   6                 17  ...
# 2   3160996     138             1                   5                 13  ...
# 3   2254091     138            10                   5                 14  ...
# 4    505689     138             9                   6                 12  ...
#
# ...

# %%
df_ords.shape
# Out:
# (32404859, 33)

# %%
# export to pickle

df_ords.to_pickle(os.path.join(path, '02_Data','Prepared_Data', 'orders_products_merged.pkl'))
