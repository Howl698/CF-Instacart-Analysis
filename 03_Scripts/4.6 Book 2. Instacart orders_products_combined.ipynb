# %% [markdown]
# # 4.6 Instacart orders and products combined

# %% [markdown]
# ## This script contains the following points:
#
# ### 1. Import and verify 'orders_products_combined.pkl'  dataframe
#
# ### 2. Import and verify 'products_checked.csv' dataframe
#
# ### 3. Merge dataframes and verify
#
# ### 4. Export as 'orders_products_merged.pkl'

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Import and verify 'orders__products_combined.pkl'  and dataframes

# %%
path = r'C:\Users\howl6\OneDrive\Certificates\CareerFoundry\Coursework\Data_Immersion\Chapter 4\Instacart Basket Analysis'

# %%
# Import 'orders_products_combined.pkl' dataframe

df_combined = pd.read_pickle(os.path.join(path,'02_Data','Prepared_Data', 'orders_products_combined.pkl'))

# %%
# view rows, columns for df_combined

df_combined.shape
# Out:
# (32434489, 11)

# %%
# view top 5 rows

df_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_time_order  product_id  add_to_cart_order  \
# 0                     NaN              True         196                  1
# 1                     NaN              True       14084                  2
# 2                     NaN              True       12427                  3
# 3                     NaN              True       26088                  4
# 4                     NaN              True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
# view bottom 5 rows

df_combined.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_time_of_day  days_since_prior_order  first_time_order  \
# 32434484                 12                     7.0             False
# 32434485                 12                     7.0             False
# 32434486                 12                     7.0             False
# 32434487                 12                     7.0             False
# 32434488                 12                     7.0             False
#
#           product_id  add_to_cart_order  reordered _merge
# 32434484       14197                  5          1   both
# ...

# %%
# Drop '_merge' column

df_combined =  df_combined.drop (columns = ['_merge'])

# %%
# view rows, columns

df_combined.shape
# Out:
# (32434489, 10)

# %%
# view top 5 rows

df_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_time_order  product_id  add_to_cart_order  \
# 0                     NaN              True         196                  1
# 1                     NaN              True       14084                  2
# 2                     NaN              True       12427                  3
# 3                     NaN              True       26088                  4
# 4                     NaN              True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# ...

# %%
# Import 'df_prods' csv dataframe

df_prods = pd.read_csv(os.path.join(path,'02_Data','Prepared_Data', 'CSV_files', 'products_checked.csv'), index_col=False)

# %%
# view rows, columns of df_prods

df_prods.shape
# Out:
# (49672, 6)

# %%
# view top 5 rows

df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# one column'Unnamed: 0' dropped

df_prods = df_prods.drop (columns = ['Unnamed: 0'])

# %%
# view rows, columns

df_prods.shape
# Out:
# (49672, 5)

# %%
# view top 5 rows

df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ### 2. Merge dataframes

# %%
# merge df_prods and df_combined dataframes

df_merged_prod = df_prods.merge(df_combined, on = 'product_id', indicator = True)

# %%
# view top 5 rows of df_merged_prod

df_merged_prod.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
# view rows, columns

df_merged_prod.shape
# Out:
# (32404859, 15)

# %%
# export data to pkl

df_merged_prod.to_pickle(os.path.join(path, '02_Data','Prepared_Data', 'orders_products_merged.pkl'))
